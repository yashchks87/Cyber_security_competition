# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
spam = pd.read_csv('./FinalDataset/Spam.csv')
malware = pd.read_csv('./FinalDataset/Malware.csv')

# %%
frames = [spam, malware]

# %%
finalData = pd.concat(frames)

# %%
finalData.shape
# Out:
# (28972, 80)

# %%
# With benign
x = finalData['URL_Type_obf_Type'].value_counts()
x = x.to_dict()
keys_final = list(x.keys())
values_final = list(x.values())
plt.xlim(6000, 16000)
plt.barh(keys_final, values_final)
# Out:
# <BarContainer object of 3 artists>

# %%
# Without benigh
y = finalData[finalData.URL_Type_obf_Type != 'benign']
y = y['URL_Type_obf_Type'].value_counts()
y = y.to_dict()
keys_final1 = list(y.keys())
values_final1 = list(y.values())
plt.barh(keys_final1, values_final1)
plt.xlim(6500, 7000)
plt.xticks(range(6700, 6900, 30))
# Change orientation...
# Out:
# ([<matplotlib.axis.XTick at 0x11623d3c8>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %%
y
# Out:
# {'malware': 6712, 'spam': 6698}

# %%
finalData.corr()
# Out:
#                                  Querylength  domain_token_count  \
# Querylength                         1.000000            0.101858
# domain_token_count                  0.101858            1.000000
# path_token_count                   -0.093149           -0.097963
# avgdomaintokenlen                  -0.059476           -0.376705
# longdomaintokenlen                  0.045904           -0.057056
# avgpathtokenlen                    -0.135874           -0.043357
# tld                                 0.101858            1.000000
# charcompvowels                      0.824905            0.026384
# charcompace                         0.872695            0.106519
# ldl_url                             0.983227            0.118815
# ldl_domain                         -0.045824            0.043910
# ldl_path                            0.983299            0.117632
# ldl_filename                        0.006867           -0.018927
# ...
